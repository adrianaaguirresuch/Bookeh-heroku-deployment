# %% [markdown]
# # Supervised Regression
#
# ## Problem Definition
#
# ### Context
# Joe Blogs is about to start a job that requires him to wake up super early every morning. Unfortunately, he knows that he’s a light sleeper, and has experiences of being disturbed by rowdy pedestrians on the streets. Before he chooses an apartment, he wants to build a model to predict the potential pedestrian noise levels at night. The exact neighbourhood he’s moving to doesn’t have noise data, but an adjoining one does.
#
# ### Objective
# Predict the amount of pedestrian noise levels at night.

# %%
# Colab
from google.colab import files
import io

# Data manipulation
import numpy as np
import pandas as pd

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Machine learning
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Importing Data

# %%
# Upload CSV file and store in a pandas dataframe
uploaded_csv = files.upload()
df = pd.read_csv(io.BytesIO(uploaded_csv['supervised-regression-data.csv']))
# Out:
#      <input type="file" id="files-b96cb4e0-8e9b-4ff4-9d24-53c3547d13c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b96cb4e0-8e9b-4ff4-9d24-53c3547d13c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supervised-regression-data.csv to supervised-regression-data.csv

# %% [markdown]
# ## Inspecting DataFrame

# %%
# Interpret the dataset
df.describe().T
# Out:
#                                count          mean  ...           75%            max
# HumanNoiseNight               4588.0     34.801755  ...     37.766336      72.078884
# TrafficNoiseDay               4588.0     53.156858  ...     61.614710      81.396175
# TrafficNoiseNight             3149.0     45.936548  ...     54.814401      74.808621
# Accidents                     4588.0     13.811247  ...     19.000000      44.000000
# Bars                          4588.0     11.133391  ...     18.000000      47.000000
# OldTown                       4588.0  33510.333261  ...  67419.250000  133499.000000
# ProtectedBuildings            4588.0   1035.531604  ...    158.000000   24445.000000
# UrbanDensification            4588.0  41426.468178  ...  64499.750000  261005.000000
# multi_family_houses           4588.0   4062.238884  ...      0.000000  108641.000000
# single_family_houses          4588.0   1444.624019  ...      0.000000   52259.000000
# Community_Endowments          4588.0  18181.440497  ...  25286.250000  109002.000000
# Endowment_protection_housing  4588.0    148.284002  ...      0.000000    2994.000000
# SpecificArrangement           4588.0   5024.192023  ...   6658.000000   50416.000000
# ForestPark                    4588.0     18.190933  ...      0.000000    3132.000000
# UrbanParks                    4588.0  13282.779861  ...  18186.000000  157621.000000
# Infrastructure                4588.0   1339.375109  ...    562.000000   35864.000000
# PhysicalRemodeling            4588.0    355.357454  ...      0.000000   12686.000000
# UrbanRenewal                  4588.0      4.333261  ...      0.000000     141.000000
# TechnicalFacilities           4588.0    215.836312  ...      0.000000    7000.000000
# RailwaySystem                 4588.0    584.388187  ...      0.000000   37763.000000
# PortSystem                    4588.0     98.309721  ...      0.000000    6378.000000
# Transformation(EQUIPMENT)     4588.0    418.990846  ...      0.000000   13394.000000
# Transformation(PARC)          4588.0    750.657803  ...      0.000000   24976.000000
# PrivateGreen                  4588.0      8.958152  ...      0.000000     829.000000
#
# [24 rows x 8 columns]

# %%
# Finding correlation
corr = df.corr()
c1 = corr.abs().unstack()
list(c1.sort_values(ascending=False).items())[len(df.columns)::2][:5]
# Out:
# [(('TrafficNoiseNight', 'TrafficNoiseDay'), 0.9156754655878607),
#  (('UrbanRenewal', 'ProtectedBuildings'), 0.7797917637870427),
#  (('ProtectedBuildings', 'TechnicalFacilities'), 0.6190983777471941),
#  (('UrbanDensification', 'OldTown'), 0.5346268840954866),
#  (('OldTown', 'Bars'), 0.5194773766936771)]

# %%
# Visualise the correlation
sns.pairplot(df[['TrafficNoiseDay', 'TrafficNoiseNight']])

# %%
# See density of points
traffic_noise_day = df[df['TrafficNoiseNight'].notnull()]['TrafficNoiseDay']
traffic_noise_night = df[df['TrafficNoiseNight'].notnull()]['TrafficNoiseNight']
plt.hist2d(traffic_noise_day, traffic_noise_night)
# Out:
# (array([[  6.,   6.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [  7.,  47.,  19.,   0.,   1.,   0.,   0.,   0.,   0.,   0.],
#         [  1.,  70., 190.,  23.,   0.,   1.,   1.,   0.,   0.,   0.],
#         [  0.,  14., 151., 219.,  18.,   2.,   3.,   1.,   0.,   0.],
#         [  2.,   6.,  46., 176., 171.,  26.,   8.,   3.,   1.,   0.],
#         [  0.,   3.,  25.,  52., 183., 257.,  41.,   7.,   1.,   0.],
#         [  0.,   0.,   9.,  22.,  27., 238., 263.,  52.,   6.,   0.],
#         [  0.,   0.,   0.,   0.,  10.,  13., 208., 216.,  33.,   1.],
#         [  0.,   0.,   0.,   0.,   0.,   0.,   8.,  97., 109.,   3.],
#         [  0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.,  30.,  14.]]),
#  array([20.64668497, 26.55029303, 32.45390108, 38.35750914, 44.26111719,
#         50.16472525, 56.0683333 , 61.97194136, 67.87554942, 73.77915747,
#         79.68276553]),
#  array([16.77508806, 22.5784414 , 28.38179473, 34.18514806, 39.9885014 ,
#         45.79185473, 51.59520806, 57.39856139, 63.20191473, 69.00526806,
#         74.80862139]),
#  <matplotlib.collections.QuadMesh at 0x7f86d8c0f850>)

# %% [markdown]
# ## Modelling Collinearity

# %%
# Extract data
df_without_nan = df.loc[df['TrafficNoiseNight'].notnull()]
input_npa = np.array(df_without_nan['TrafficNoiseDay']).reshape((-1, 1))
output_npa = np.array(df_without_nan['TrafficNoiseNight'])

# %%
# Build model
lin_reg_model = LinearRegression()
lin_reg_model.fit(input_npa, output_npa)
# Out:
# LinearRegression()

# %%
# Evaluate model (r sqaure)
lin_reg_model.score(input_npa, output_npa)
# Out:
# 0.8384615582795446

# %%
# Visualising linear regression
x = input_npa
m = lin_reg_model.coef_
b = lin_reg_model.intercept_

plt.hist2d(input_npa.flatten(), output_npa)
plt.plot(x, m * x + b, color='r')

# %% [markdown]
# ## Model-based Imputation

# %%
# Predict on missing values
mbi_df = df.copy()
inputed = lin_reg_model.predict(np.array(mbi_df['TrafficNoiseDay']).reshape(-1, 1))
mbi_df['TrafficNoiseNight'].fillna(pd.Series(inputed), inplace=True)

# %%
# Confirm
mbi_df.describe().T
# Out:
#                                count          mean  ...           75%            max
# HumanNoiseNight               4588.0     34.801755  ...     37.766336      72.078884
# TrafficNoiseDay               4588.0     53.156858  ...     61.614710      81.396175
# TrafficNoiseNight             4588.0     46.055498  ...     54.635662      74.808621
# Accidents                     4588.0     13.811247  ...     19.000000      44.000000
# Bars                          4588.0     11.133391  ...     18.000000      47.000000
# OldTown                       4588.0  33510.333261  ...  67419.250000  133499.000000
# ProtectedBuildings            4588.0   1035.531604  ...    158.000000   24445.000000
# UrbanDensification            4588.0  41426.468178  ...  64499.750000  261005.000000
# multi_family_houses           4588.0   4062.238884  ...      0.000000  108641.000000
# single_family_houses          4588.0   1444.624019  ...      0.000000   52259.000000
# Community_Endowments          4588.0  18181.440497  ...  25286.250000  109002.000000
# Endowment_protection_housing  4588.0    148.284002  ...      0.000000    2994.000000
# SpecificArrangement           4588.0   5024.192023  ...   6658.000000   50416.000000
# ForestPark                    4588.0     18.190933  ...      0.000000    3132.000000
# UrbanParks                    4588.0  13282.779861  ...  18186.000000  157621.000000
# Infrastructure                4588.0   1339.375109  ...    562.000000   35864.000000
# PhysicalRemodeling            4588.0    355.357454  ...      0.000000   12686.000000
# UrbanRenewal                  4588.0      4.333261  ...      0.000000     141.000000
# TechnicalFacilities           4588.0    215.836312  ...      0.000000    7000.000000
# RailwaySystem                 4588.0    584.388187  ...      0.000000   37763.000000
# PortSystem                    4588.0     98.309721  ...      0.000000    6378.000000
# Transformation(EQUIPMENT)     4588.0    418.990846  ...      0.000000   13394.000000
# Transformation(PARC)          4588.0    750.657803  ...      0.000000   24976.000000
# PrivateGreen                  4588.0      8.958152  ...      0.000000     829.000000
#
# [24 rows x 8 columns]

# %% [markdown]
# ## Dataset Division and Scaling

# %%
OUTPUT_COLUMN = 'HumanNoiseNight'

# Split dataframe into training and testing dataframe (90% split)
train_df = mbi_df.sample(frac=0.9)
test_df = mbi_df.drop(train_df.index)

# Seperate input and output columns
train_input_df = train_df.copy()
train_output_df = train_input_df.pop(OUTPUT_COLUMN)

test_input_df = test_df.copy()
test_output_df = test_input_df.pop(OUTPUT_COLUMN)

# Scaler (remapping)
input_scaler = MinMaxScaler(feature_range=(0,1))
scaled_train_input_df = pd.DataFrame(
    input_scaler.fit_transform(train_input_df),
    columns=train_input_df.columns
)
scaled_test_input_df = input_scaler.transform(test_input_df)

output_scaler = MinMaxScaler()
scaled_train_output_df = pd.DataFrame(
    output_scaler.fit_transform(np.array(train_output_df).reshape(-1, 1)),
    columns=[OUTPUT_COLUMN]
)
scaled_test_output_df = output_scaler.transform(np.array(test_output_df).reshape(-1, 1))

scaled_train_input_df
# Out:
#       TrafficNoiseDay  TrafficNoiseNight  ...  Transformation(PARC)  PrivateGreen
# 0            0.928603           0.893248  ...              0.000000       0.000000
# 1            0.606690           0.583591  ...              0.000000       0.000000
# 2            0.743418           0.675186  ...              0.081638       0.661037
# 3            0.702445           0.626401  ...              0.565623       0.000000
# 4            0.507986           0.488646  ...              0.000000       0.000000
# ...               ...                ...  ...                   ...            ...
# 4124         0.401340           0.332956  ...              0.000000       0.000000
# 4125         0.503126           0.372857  ...              0.000000       0.000000
# 4126         0.378271           0.363869  ...              0.000000       0.000000
# 4127         0.119564           0.115012  ...              0.049488       0.000000
# 4128         0.264852           0.253715  ...              0.000000       0.000000
#
# [4129 rows x 23 columns]

# %% [markdown]
# ## Approach 1: Multivariate Linear Regression

# %%
input_shape = [23]
# input_shape = [*scaled_train_input_df.shape[1:]]
# Build model
lin_reg_model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape)
])
lin_reg_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 24
#
# =================================================================
# Total params: 24
# Trainable params: 24
# Non-trainable params: 0
# _________________________________________________________________

# %%
lin_reg_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.MSE
)

# %%
lin_reg_history = lin_reg_model.fit(
    x=scaled_train_input_df,
    y=scaled_train_output_df,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 3s 4ms/step - loss: 0.0647 - val_loss: 0.0451
# Epoch 2/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0463 - val_loss: 0.0385
# Epoch 3/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0403 - val_loss: 0.0339
# Epoch 4/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.0307
# Epoch 5/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0282
# Epoch 6/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0304 - val_loss: 0.0263
# Epoch 7/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.0248
# Epoch 8/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0270 - val_loss: 0.0236
# Epoch 9/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0257 - val_loss: 0.0225
# Epoch 10/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0246 - val_loss: 0.0216
# Epoch 11/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0236 - val_loss: 0.0208
# Epoch 12/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0227 - val_loss: 0.0201
# Epoch 13/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0220 - val_loss: 0.0195
# Epoch 14/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0214 - val_loss: 0.0190
# Epoch 15/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0208 - val_loss: 0.0185
# Epoch 16/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0203 - val_loss: 0.0181
# Epoch 17/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 18/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0174
# Epoch 19/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0170
# Epoch 20/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0167
# Epoch 21/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 22/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0163
# Epoch 23/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0161
# Epoch 24/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0159
# Epoch 25/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0157
# Epoch 26/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0156
# Epoch 27/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0155
# Epoch 28/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0168 - val_loss: 0.0152
# Epoch 29/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0152
# Epoch 30/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0150
# Epoch 31/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0164 - val_loss: 0.0149
# Epoch 32/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0162 - val_loss: 0.0147
# Epoch 33/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0146
# Epoch 34/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0146
# Epoch 35/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0159 - val_loss: 0.0145
# Epoch 36/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0158 - val_loss: 0.0144
# Epoch 37/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0157 - val_loss: 0.0143
# Epoch 38/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0156 - val_loss: 0.0143
# Epoch 39/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0142
# Epoch 40/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.0141
# Epoch 41/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.0140
# Epoch 42/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0153 - val_loss: 0.0140
# Epoch 43/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0152 - val_loss: 0.0139
# Epoch 44/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0151 - val_loss: 0.0139
# Epoch 45/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0139
# Epoch 46/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.0138
# Epoch 47/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.0137
# Epoch 48/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0149 - val_loss: 0.0136
# Epoch 49/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0136
# Epoch 50/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0135
# Epoch 51/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0135
# Epoch 52/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0135
# Epoch 53/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.0135
# Epoch 54/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 55/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0145 - val_loss: 0.0134
# Epoch 56/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0145 - val_loss: 0.0133
# Epoch 57/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0145 - val_loss: 0.0133
# Epoch 58/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0133
# Epoch 59/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0132
# Epoch 60/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0132
# Epoch 61/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0143 - val_loss: 0.0132
# Epoch 62/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0143 - val_loss: 0.0131
# Epoch 63/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0131
# Epoch 64/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0131
# Epoch 65/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0131
# Epoch 66/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0130
# Epoch 67/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0130
# Epoch 68/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0131
# Epoch 69/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0141 - val_loss: 0.0130
# Epoch 70/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 71/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 72/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 73/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 74/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 75/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0129
# Epoch 76/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0129
# Epoch 77/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0128
# Epoch 78/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0128
# Epoch 79/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 80/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 81/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 82/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0127
# Epoch 83/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0127
# Epoch 84/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 85/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 86/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 87/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 88/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 89/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0127
# Epoch 90/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 91/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 92/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 93/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 94/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 95/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 96/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 97/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0126
# Epoch 98/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0126
# Epoch 99/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0126
# Epoch 100/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0126

# %% [markdown]
# ## Approach 2: Logistic Regression

# %%
input_shape = [23]

# Build model
log_reg_model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape, activation='sigmoid')
])
log_reg_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 24
#
# =================================================================
# Total params: 24
# Trainable params: 24
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_reg_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.MSE
)

# %%
log_reg_history = log_reg_model.fit(
    x=scaled_train_input_df,
    y=scaled_train_output_df,
    epochs=100,
    validation_split=0.2 )
# Out:
# Epoch 1/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0601 - val_loss: 0.0512
# Epoch 2/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0467 - val_loss: 0.0410
# Epoch 3/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0382 - val_loss: 0.0346
# Epoch 4/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0327 - val_loss: 0.0307
# Epoch 5/100
# 104/104 [==============================] - 0s 4ms/step - loss: 0.0293 - val_loss: 0.0282
# Epoch 6/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.0266
# Epoch 7/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0256
# Epoch 8/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0247 - val_loss: 0.0249
# Epoch 9/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0245
# Epoch 10/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0241
# Epoch 11/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0239
# Epoch 12/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0230 - val_loss: 0.0237
# Epoch 13/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0228 - val_loss: 0.0236
# Epoch 14/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0234
# Epoch 15/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0233
# Epoch 16/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0232
# Epoch 17/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0231
# Epoch 18/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0230
# Epoch 19/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0220 - val_loss: 0.0229
# Epoch 20/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0228
# Epoch 21/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0227
# Epoch 22/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0226
# Epoch 23/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0216 - val_loss: 0.0225
# Epoch 24/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0215 - val_loss: 0.0224
# Epoch 25/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0223
# Epoch 26/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0213 - val_loss: 0.0222
# Epoch 27/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0221
# Epoch 28/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0211 - val_loss: 0.0221
# Epoch 29/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0210 - val_loss: 0.0220
# Epoch 30/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0219
# Epoch 31/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0218
# Epoch 32/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.0217
# Epoch 33/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0207 - val_loss: 0.0216
# Epoch 34/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0206 - val_loss: 0.0215
# Epoch 35/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0205 - val_loss: 0.0215
# Epoch 36/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0214
# Epoch 37/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0213
# Epoch 38/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0203 - val_loss: 0.0212
# Epoch 39/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0212
# Epoch 40/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0201 - val_loss: 0.0211
# Epoch 41/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0201 - val_loss: 0.0210
# Epoch 42/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0200 - val_loss: 0.0209
# Epoch 43/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0209
# Epoch 44/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0208
# Epoch 45/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0207
# Epoch 46/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0197 - val_loss: 0.0207
# Epoch 47/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0206
# Epoch 48/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0205
# Epoch 49/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0204
# Epoch 50/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0204
# Epoch 51/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0194 - val_loss: 0.0203
# Epoch 52/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0203
# Epoch 53/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0202
# Epoch 54/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0201
# Epoch 55/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0201
# Epoch 56/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0191 - val_loss: 0.0200
# Epoch 57/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0199
# Epoch 58/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0190 - val_loss: 0.0199
# Epoch 59/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0189 - val_loss: 0.0198
# Epoch 60/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0188 - val_loss: 0.0198
# Epoch 61/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0197
# Epoch 62/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0197
# Epoch 63/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0187 - val_loss: 0.0196
# Epoch 64/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0196
# Epoch 65/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0195
# Epoch 66/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0194
# Epoch 67/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0194
# Epoch 68/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0184 - val_loss: 0.0193
# Epoch 69/100
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0193
# Epoch 70/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0192
# Epoch 71/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0192
# Epoch 72/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0191
# Epoch 73/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0191
# Epoch 74/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0190
# Epoch 75/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0190
# Epoch 76/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0190
# Epoch 77/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0180 - val_loss: 0.0189
# Epoch 78/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0189
# Epoch 79/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 80/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0188
# Epoch 81/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0187
# Epoch 82/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0187
# Epoch 83/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 84/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 85/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0186
# Epoch 86/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0185
# Epoch 87/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0185
# Epoch 88/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0184
# Epoch 89/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0184
# Epoch 90/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0184
# Epoch 91/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0183
# Epoch 92/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 93/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0182
# Epoch 94/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0182
# Epoch 95/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 96/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0181
# Epoch 97/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0181
# Epoch 98/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0181
# Epoch 99/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0171 - val_loss: 0.0180
# Epoch 100/100
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0180

# %% [markdown]
# ## Approach 3: The Neural Network

# %%
# layers.Dense(64, input_shape=input_shape, activation='relu'),
# layers.Dense(32, activation='relu'),
# layers.Dense(1, activation='sigmoid'),

input_shape = [23]

# Build model
neunet_reg_model = keras.Sequential([
    layers.Dense(32, input_shape=input_shape, activation='sigmoid')
])
neunet_reg_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-191b0ba73119> in <module>()
#       6
#       7 # Build model
# ----> 8 neunet_reg_model = keras.Sequential([
#       9     layers.Dense(32, input_shape=input_shape, activation='sigmoid')
#      10 ])
#
# NameError: name 'keras' is not defined

# %%
neunet_reg_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    loss=tf.keras.losses.MSE
)

# %%
neunet_reg_history = neunet_reg_model.fit(
    x=scaled_train_input_df,
    y=scaled_train_output_df,
    epochs=200,
    validation_split=0.2 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d040188ac522> in <module>()
# ----> 1 neunet_reg_history = neunet_reg_model.fit(
#       2     x=scaled_train_input_df,
#       3     y=scaled_train_output_df,
#       4     epochs=200,
#       5     validation_split=0.2 )
#
# NameError: name 'neunet_reg_model' is not defined

# %% [markdown]
# ## Assessing Model Performance

# %%
# Helper functions
def see_final_loss(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    return hist.tail()

def plot_loss(history):
    plot = plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
    return plot

# %%
plot_loss(neunet_reg_history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a29d38c06663> in <module>()
# ----> 1 plot_loss(neunet_reg_history)
#
# NameError: name 'neunet_reg_history' is not defined

# %%
# Sample outputs
INDEX = 0
x = scaled_train_input_df.iloc[INDEX]
y = scaled_train_output_df.iloc[INDEX]

x_npa = np.array(x).reshape(1, -1)

mv_lin_reg_pred = mv_lin_reg_model.predict(x_npa)
log_reg_pred = log_reg_model.predict(x_npa)
neural_net_pred = neural_net_model.predict(x_npa)

print(f"""
Predicting on...
{pd.DataFrame(input_scaler.inverse_transform(x_npa), columns=scaled_train_input_df.columns).T}

Expected Output: {output_scaler.inverse_transform([y])[0][0]} db

Multivariate Linear Regression Prediction: {output_scaler.inverse_transform(mv_lin_reg_pred)[0][0]} db
Logistic Regression Prediction: {output_scaler.inverse_transform(log_reg_pred)[0][0]} db
Neural Network Prediction: {output_scaler.inverse_transform(neural_net_pred)[0][0]} db
"""
)
